# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from datetime import datetime
import requests
import pytz
import os 
import glob 
import math
import time
# %matplotlib inline
import datashader as ds
import datashader.transfer_functions as tf

# %% [markdown]
# # Reading Earthquake Data

# %%
df = pd.read_csv(r'C:\Users\Ramiro\Downloads\Quakes.csv')

# %% [markdown]
# # Reading Variables from Data

# %%
time=df.time
latitude=df.latitude
longitude=df.longitude
magnitude=df.mag

# %%
magg=df.mag[1:len(magnitude)]  #was getting error using time in the plot
timee=df.time[1:len(time)]

# %% [markdown]
# # Magnitude vs Time Plot

# %%
plt.title('Magnitude vs Time')
plt.scatter(timee,magg, s=10)
plt.ylabel('Magnitude')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Location of Earthquakes

# %%
fig, ax = plt.subplots(figsize = (15,12))
ax.scatter(longitude,latitude,s=size*.2)
plt.title('Location of Earthquakes')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
ax.imshow(map,extent=[longmin, longmax,lmin,lmax])

# %%
latitude
lmin=latitude.min()
longmax=longitude.max()
longmin=longitude.min()
lmax=latitude.max()

# %%
magnitude.max()
# Out:
# 7.8

# %%
magnitude.mean()
# Out:
# 3.2054014756944444

# %%
magnitude.min()
# Out:
# 2.5

# %% [markdown]
# # April 2015 Earthquakes

# %%
size=magnitude*100
fig, ax = plt.subplots(figsize = (15,12))
ax.scatter(longitude[1940:1992],latitude[1940:1992], s=size)
plt.title('Location of Earthquakes in April 2015')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
ax.imshow(map,extent=[longmin, longmax,lmin,lmax])
